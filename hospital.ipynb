# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#table contents with provider number as index
outcome.head(15)
# Out:
#                                     Hospital Name  \
# Provider Number
# 010001           SOUTHEAST ALABAMA MEDICAL CENTER
# 010005              MARSHALL MEDICAL CENTER SOUTH
# 010006             ELIZA COFFEE MEMORIAL HOSPITAL
# 010007                   MIZELL MEMORIAL HOSPITAL
# 010008                CRENSHAW COMMUNITY HOSPITAL
# 010010              MARSHALL MEDICAL CENTER NORTH
# 010011                          ST VINCENT'S EAST
# 010012             DEKALB REGIONAL MEDICAL CENTER
# 010016              SHELBY BAPTIST MEDICAL CENTER
# 010018           CALLAHAN EYE FOUNDATION HOSPITAL
# 010019             HELEN KELLER MEMORIAL HOSPITAL
# 010021                        DALE MEDICAL CENTER
# 010022                    CHEROKEE MEDICAL CENTER
# 010023               BAPTIST MEDICAL CENTER SOUTH
# 010024              JACKSON HOSPITAL & CLINIC INC
#
#                                     Address 1  Address 2  Address 3  \
# Provider Number
# ...

# %%
#first problem statement for showing histogram
outcome = pd.read_csv("outcome-of-care-measures.csv", index_col =0)
#df = pd.eval(df['outcome'])
#pd.to_numeric(outcome, errors = 'coerce')
#pd.to_numeric(outcome, errors = 'ignore')
#outcome.hist(column="Hospital 30-Day Death (Mortality) Rates from Heart Attack")
heart_failure = outcome.iloc[:,11].values
heart_failure = pd.to_numeric(heart_failure, errors = 'ignore')
heart_failure = pd.to_numeric(heart_failure, errors = 'coerce')


plt.hist(heart_failure, bins = '10')
#heart_failure[:,11].hist(bins = '10')
#heart_failure.plot(kind = 'hist')

plt.xlabel('30-day Death Rate')
plt.title('Heart Attack 30-day Death Rate')

plt.show()
# Out:
# /root/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /root/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-7b0d6326c4b0> in <module>()
#       9
#      10
# ---> 11 plt.hist(heart_failure, bins = '10')
#      12 #heart_failure[:,11].hist(bins = '10')
#      13 #heart_failure.plot(kind = 'hist')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
# ...

# %%
#second probelem statement where a function best is defined with two arguments.
def best(state, outcome):
    
    if (outcome != "heart attack" or outcome != "heart failure" or outcome != "pneumonia")
        print("invalid outcome")
    
    index = elif (outcome == "heart attack", 11, elif (outcome == "heart failure", 17, 23))
    
    
    data = read.csv("outcome-of-care-measures.csv")
    data[,index] = suppressWarnings(as.numeric(data[,index]))
    data = na.omit(data)
    
   
    states = table(data$State)
    if (state != names(states)) 
        print("invalid state")
# Out:
#   File "<ipython-input-85-8e4f240c379a>", line 4
#     if (outcome != "heart attack" or outcome != "heart failure" or outcome != "pneumonia")
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
#problem statement 3
def rankhospital(state, outcome, num="best"):
    #Invalid outcome input type
    if (outcome != c("heart attack", "heart failure", "pneumonia")) 
        print("invalid outcome")
    
    
    #Get index for our given outcome string.
    index = elif(outcome == "heart attack", 11 and elif (outcome == "heart failure", 17, 23))
    
    #Read and coerce our dataset while suppressing warnings and removing NA's.
    data = read.csv("outcome-of-care-measures.csv", colClasses="character")
    data[:,index] = suppressWarnings(pd.to_numeric(data[:,index]))
    data = na.omit(data)
    
    #Invalid state input or no observations
    states = table(data$State)
    if (state != names(states)) 
        print("invalid state")
